# %%
# the TestEnv environment is used to simply simulate the network
from flow.envs import TestEnv

# the Experiment class is used for running simulations
from flow.core.experiment import Experiment

# the base network class
from flow.networks import Network
from flow.networks import InductionNet
from flow.envs import Env

# all other imports are standard
from flow.core.params import VehicleParams
from flow.core.params import NetParams
from flow.core.params import InitialConfig
from flow.core.params import EnvParams
from flow.core.params import TrafficLightParams

# create some default parameters parameters
HORIZON = 10000
env_params = EnvParams(horizon=HORIZON)
initial_config = InitialConfig()

# %%
LuST_dir = "/home/valentin/flow/personal_tests"

# %%
from flow.core.params import SumoParams

sim_params = SumoParams(render=False, sim_step=1)

# %%
import os

net_params = NetParams(
    template={
        # network geometry features
        "net": os.path.join(LuST_dir, "lemgo.net.xml"),
        # features associated with the properties of drivers
        "vtype": os.path.join(LuST_dir, "vtypes.add.xml"),
        # features associated with the routes vehicles take
        "rou": os.path.join(LuST_dir, "lemgo2.rou.xml"),
        "det": os.path.join(LuST_dir, "lemgo.add.xml")
    }
)

# %% [markdown]
# ## Create custom Traffic lights:

# %%
tf_logic = TrafficLightParams(baseline=False)
nodes = ["27403692", "27431768", "27153964", "27153945"]
params0 = [{"duration": "42", "minDur": "8", "maxDur": "50", "state": "GGGgrr"},
           {"duration": "3", "state": "yyyyrr"},
           {"duration": "42", "minDur": "8", "maxDur": "50", "state": "GrrrGG"},
           {"duration": "3", "state": "yrrryy"}]
params1 = [{"duration": "42", "minDur": "8", "maxDur": "50", "state": "GGGgrr"},
           {"duration": "3", "state": "yyyyrr"},
           {"duration": "42", "minDur": "8", "maxDur": "50", "state": "GrrrGG"},
           {"duration": "3", "state": "yrrryy"}]
params2 = [{"duration": "33", "minDur": "8", "maxDur": "40", "state": "rrrGGgrrrGGg"},
           {"duration": "3", "state": "rrryygrrryyg"},
           {"duration": "6", "minDur": "5", "maxDur": "10", "state": "rrrrrGrrrrrG"},
           {"duration": "3", "state": "rrrrryrrrrry"},
           {"duration": "33", "minDur": "8", "maxDur": "40", "state": "GGgrrrGGgrrr"},
           {"duration": "3", "state": "yygrrryygrrr"},
           {"duration": "6", "minDur": "5", "maxDur": "10", "state": "rrGrrrrrGrrr"},
           {"duration": "3", "state": "rryrrrrryrrr"}]
params3 = [{"duration": "42", "minDur": "8", "maxDur": "50", "state": "GgrrGG"},
           {"duration": "3", "state": "yyrryy"},
           {"duration": "42", "minDur": "8", "maxDur": "50", "state": "rrGGGr"},
           {"duration": "3", "state": "rryyyr"}]

tf_logic.add(node_id=nodes[0], tls_type="actuated", programID="1",
             offset=None, phases=params0, maxGap=4.0, detectorGap=0.9, showDetectors=True)
#tf_logic.add(node_id=nodes[1], tls_type="actuated", programID="1",
#             offset=None, phases=params0, maxGap=4.0, detectorGap=0.9, showDetectors=True)
tf_logic.add(node_id=nodes[2], tls_type="actuated", programID="1",
             offset=None, phases=params2, maxGap=4.0, detectorGap=0.9, showDetectors=True)
tf_logic.add(node_id=nodes[3], tls_type="actuated", programID="1",
             offset=None, phases=params3, maxGap=4.0, detectorGap=0.9, showDetectors=True)

# %% [markdown]
# #### 3.2.3 Running the Modified Simulation
#
# Finally, the fully imported simulation can be run as follows.
#
# **Warning**: the network takes time to initialize while the departure positions and times and vehicles are specified.

# %%
# create the network
network = InductionNet(
    name="template",
    net_params=net_params,
    vehicles=VehicleParams(),
    traffic_lights=tf_logic
)

# create the environment
env = TestEnv(
    env_params=env_params,
    sim_params=sim_params,
    network=network
)

# run the simulation for 100000 steps
exp = Experiment(env=env)
_ = exp.run(1, 100)
# Out:
# Round 0, return: 0
# Average, std return: 0.0, 0.0
# Average, std speed: 14.806430067688154, 0.0

# %%
# This is the custom environment
# Needs to be important in order to work properly in flow
from flow.envs import SimpleEnv
env_name = SimpleEnv

# %%
# Creating flow_params. Make sure the dictionary keys are as specified. 
flow_params = dict(
    # name of the experiment
    exp_tag="first_exp",
    # name of the flow environment the experiment is running on
    env_name=env_name,
    # name of the network class the experiment uses
    network=InductionNet,
    # simulator that is used by the experiment
    simulator='traci',
    # sumo-related parameters (see flow.core.params.SumoParams)
    sim=sim_params,
    # environment related parameters (see flow.core.params.EnvParams)
    env=env_params,
    # network-related parameters (see flow.core.params.NetParams and
    # the network's documentation or ADDITIONAL_NET_PARAMS component)
    net=net_params,
    # vehicles to be placed in the network at the start of a rollout 
    # (see flow.core.vehicles.Vehicles)
    veh=VehicleParams(),
    # (optional) parameters affecting the positioning of vehicles upon 
    # initialization/reset (see flow.core.params.InitialConfig)
    initial=initial_config
)

# %%
import json

import ray
try:
    from ray.rllib.agents.agent import get_agent_class
except ImportError:
    from ray.rllib.agents.registry import get_agent_class
from ray.tune import run_experiments
from ray.tune.registry import register_env

from flow.utils.registry import make_create_env
from flow.utils.rllib import FlowParamsEncoder
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/compat/v2_compat.py:65: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
# number of parallel workers
N_CPUS = 2
# number of rollouts per training iteration
N_ROLLOUTS = 1

ray.init(num_cpus=N_CPUS)
# Out:
# 2019-12-13 19:06:36,693	INFO node.py:498 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-12-13_19-06-36_693393_22893/logs.
# 2019-12-13 19:06:36,809	INFO services.py:409 -- Waiting for redis server at 127.0.0.1:46228 to respond...
# 2019-12-13 19:06:36,947	INFO services.py:409 -- Waiting for redis server at 127.0.0.1:28389 to respond...
# 2019-12-13 19:06:36,958	INFO services.py:809 -- Starting Redis shard with 1.65 GB max memory.
# 2019-12-13 19:06:37,014	INFO node.py:512 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-12-13_19-06-36_693393_22893/logs.
# 2019-12-13 19:06:37,017	WARNING services.py:1330 -- WARNING: The default object store size of 2.48 GB will use more than 50% of the available memory on this node (3.63 GB). Consider setting the object store memory manually to a smaller size to avoid memory contention with other applications.
# 2019-12-13 19:06:37,019	INFO services.py:1475 -- Starting the Plasma object store with 2.48 GB memory using /dev/shm.
# {'node_ip_address': '192.168.101.101',
#  'redis_address': '192.168.101.101:46228',
#  'object_store_address': '/tmp/ray/session_2019-12-13_19-06-36_693393_22893/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2019-12-13_19-06-36_693393_22893/sockets/raylet',
#  'webui_url': None,
#  'session_dir': '/tmp/ray/session_2019-12-13_19-06-36_693393_22893'}

# %%
# The algorithm or model to train. This may refer to "
#      "the name of a built-on algorithm (e.g. RLLib's DQN "
#      "or PPO), or a user-defined trainable function or "
#      "class registered in the tune registry.")
alg_run = "PPO"

BATCH_SIZE = 10000

agent_cls = get_agent_class(alg_run)
config = agent_cls._default_config.copy()
config["num_workers"] = N_CPUS - 1  # number of parallel workers
config["train_batch_size"] = BATCH_SIZE  # batch size
config["gamma"] = 0.999  # discount rate
config["model"].update({"fcnet_hiddens": [16, 16]})  # size of hidden layers in network
config["use_gae"] = True  # using generalized advantage estimation
config["lambda"] = 0.97  
config["sgd_minibatch_size"] = min(16 * 1024, config["train_batch_size"])  # stochastic gradient descent
config["kl_target"] = 0.02  # target KL divergence
config["num_sgd_iter"] = 10  # number of SGD iterations
config["horizon"] = HORIZON  # rollout horizon
config["vf_clip_param"] = 50000.0

# save the flow params for replay
flow_json = json.dumps(flow_params, cls=FlowParamsEncoder, sort_keys=True,
                       indent=4)  # generating a string version of flow_params
config['env_config']['flow_params'] = flow_json  # adding the flow_params to config dict
config['env_config']['run'] = alg_run

# Call the utility function make_create_env to be able to 
# register the Flow env for this experiment
create_env, gym_name = make_create_env(params=flow_params, version=0)

# Register as rllib env with Gym
register_env(gym_name, create_env)

# %%
## The algorithm or model to train. This may refer to "
##      "the name of a built-on algorithm (e.g. RLLib's DQN "
##      "or PPO), or a user-defined trainable function or "
##      "class registered in the tune registry.")
#alg_run = "A3C"
#
#BATCH_SIZE = HORIZON * N_ROLLOUTS
#
#agent_cls = get_agent_class(alg_run)
#config = agent_cls._default_config.copy()
#config["num_workers"] = N_CPUS - 1  # number of parallel workers
#config["train_batch_size"] = BATCH_SIZE  # batch size
#config["sample_batch_size"] = BATCH_SIZE  # batch size
#config["gamma"] = 0.999  # discount rate
#config["model"].update({"fcnet_hiddens": [16, 16]})  # size of hidden layers in network
#config["horizon"] = HORIZON  # rollout horizon
#
## save the flow params for replay
#flow_json = json.dumps(flow_params, cls=FlowParamsEncoder, sort_keys=True,
#                       indent=4)  # generating a string version of flow_params
#config['env_config']['flow_params'] = flow_json  # adding the flow_params to config dict
#config['env_config']['run'] = alg_run
#
## Call the utility function make_create_env to be able to 
## register the Flow env for this experiment
#create_env, gym_name = make_create_env(params=flow_params, version=0)
#
## Register as rllib env with Gym
#register_env(gym_name, create_env)

# %%
trials = run_experiments({
    flow_params["exp_tag"]: {
        "run": alg_run,
        "env": gym_name,
        "config": {
            **config
        },
        "checkpoint_freq": 2,  # number of iterations between checkpoints
        "checkpoint_at_end": True,  # generate a checkpoint at the end
        "max_failures": 999,
        "stop": {  # stopping conditions
            "training_iteration": 10,  # number of iterations to stop after
        },
    },
})
# Out:
# 2019-12-13 19:06:37,298	INFO trial_runner.py:176 -- Starting a new experiment.
# 2019-12-13 19:06:37,337	WARNING signature.py:108 -- The function with_updates has a **kwargs argument, which is currently not supported.
# 2019-12-13 19:06:37,346	WARNING logger.py:227 -- Could not instantiate <class 'ray.tune.logger.TFLogger'> - skipping.
# 2019-12-13 19:06:37,354	ERROR log_sync.py:34 -- Log sync requires cluster to be setup with `ray up`.
# 2019-12-13 19:06:37,437	WARNING util.py:145 -- The `start_trial` operation took 0.11296272277832031 seconds to complete, which may be a performance bottleneck.
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 0/2 CPUs, 0/0 GPUs
# Memory usage on this node: 4.7/8.3 GB
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 2/2 CPUs, 0/0 GPUs
# Memory usage on this node: 4.7/8.3 GB
# Result logdir: /home/valentin/ray_results/first_exp
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - PPO_SimpleEnv-v0_0:	RUNNING
#
# (pid=22932) WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/compat/v2_compat.py:65: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# (pid=22932) Instructions for updating:
# (pid=22932) non-resource variables are not supported in the long term
# (pid=22932) 2019-12-13 19:06:40,006	WARNING ppo.py:143 -- FYI: By default, the value function will not share layers with the policy model ('vf_share_layers': False).
# (pid=22932) 2019-12-13 19:06:41,120	INFO rollout_worker.py:319 -- Creating policy evaluation worker 0 on CPU (please ignore any CUDA init errors)
# (pid=22932) 2019-12-13 19:06:41.121958: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# (pid=22932) 2019-12-13 19:06:41.145928: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2904000000 Hz
# (pid=22932) 2019-12-13 19:06:41.147590: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x42225a0 executing computations on platform Host. Devices:
# (pid=22932) 2019-12-13 19:06:41.147677: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# (pid=22932) WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ray/rllib/models/tf/fcnet_v1.py:48: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# (pid=22932) Instructions for updating:
# (pid=22932) Use keras.layers.Dense instead.
# (pid=22932) WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ray/rllib/models/tf/fcnet_v1.py:48: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# (pid=22932) Instructions for updating:
# (pid=22932) Use keras.layers.Dense instead.
# (pid=22932) WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# (pid=22932) Instructions for updating:
# (pid=22932) Please use `layer.__call__` method instead.
# (pid=22932) WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# (pid=22932) Instructions for updating:
# (pid=22932) Please use `layer.__call__` method instead.
# (pid=22932) WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ray/rllib/models/tf/tf_action_dist.py:138: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# (pid=22932) Instructions for updating:
# (pid=22932) Use `tf.cast` instead.
# (pid=22932) WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ray/rllib/models/tf/tf_action_dist.py:138: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# (pid=22932) Instructions for updating:
# (pid=22932) Use `tf.cast` instead.
# (pid=22932) 2019-12-13 19:06:41,299	INFO dynamic_tf_policy.py:324 -- Initializing loss function with dummy input:
# (pid=22932)
# (pid=22932) { 'action_prob': <tf.Tensor 'default_policy/action_prob:0' shape=(?,) dtype=float32>,
# (pid=22932)   'actions': <tf.Tensor 'default_policy/actions:0' shape=(?, 4) dtype=float32>,
# (pid=22932)   'advantages': <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
# (pid=22932)   'behaviour_logits': <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 8) dtype=float32>,
# (pid=22932)   'dones': <tf.Tensor 'default_policy/dones:0' shape=(?,) dtype=bool>,
# (pid=22932)   'new_obs': <tf.Tensor 'default_policy/new_obs:0' shape=(?, 27) dtype=float32>,
# (pid=22932)   'obs': <tf.Tensor 'default_policy/observation:0' shape=(?, 27) dtype=float32>,
# (pid=22932)   'prev_actions': <tf.Tensor 'default_policy/action:0' shape=(?, 4) dtype=float32>,
# (pid=22932)   'prev_rewards': <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
# (pid=22932)   'rewards': <tf.Tensor 'default_policy/rewards:0' shape=(?,) dtype=float32>,
# (pid=22932)   'value_targets': <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
# (pid=22932)   'vf_preds': <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>}
# (pid=22932)
# (pid=22932) 2019-12-13 19:06:42,172	INFO rollout_worker.py:742 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f1d02245fd0>}
# (pid=22932) 2019-12-13 19:06:42,172	INFO rollout_worker.py:743 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x7f1d02245d30>}
# (pid=22932) 2019-12-13 19:06:42,172	INFO rollout_worker.py:356 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x7f1d02245be0>}
# (pid=22932) 2019-12-13 19:06:42,191	INFO multi_gpu_optimizer.py:93 -- LocalMultiGPUOptimizer devices ['/cpu:0']
# (pid=22933) WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/compat/v2_compat.py:65: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# (pid=22933) Instructions for updating:
# (pid=22933) non-resource variables are not supported in the long term
# (pid=22932) 2019-12-13 19:06:44,873	WARNING util.py:47 -- Install gputil for GPU system monitoring.
# (pid=22932) WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ray/rllib/policy/tf_policy.py:570: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (pid=22932) Instructions for updating:
# (pid=22932) Prefer Variable.assign which has equivalent behavior in 2.X.
# (pid=22932) WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ray/rllib/policy/tf_policy.py:570: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (pid=22932) Instructions for updating:
# (pid=22932) Prefer Variable.assign which has equivalent behavior in 2.X.
# (pid=22933) 2019-12-13 19:06:45,565	INFO rollout_worker.py:319 -- Creating policy evaluation worker 1 on CPU (please ignore any CUDA init errors)
# (pid=22933) 2019-12-13 19:06:45.566431: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# (pid=22933) 2019-12-13 19:06:45.593560: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2904000000 Hz
# (pid=22933) 2019-12-13 19:06:45.593770: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x4fab040 executing computations on platform Host. Devices:
# (pid=22933) 2019-12-13 19:06:45.593793: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# (pid=22933) WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ray/rllib/models/tf/fcnet_v1.py:48: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# (pid=22933) Instructions for updating:
# (pid=22933) Use keras.layers.Dense instead.
# (pid=22933) WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ray/rllib/models/tf/fcnet_v1.py:48: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# (pid=22933) Instructions for updating:
# (pid=22933) Use keras.layers.Dense instead.
# (pid=22933) WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# (pid=22933) Instructions for updating:
# (pid=22933) Please use `layer.__call__` method instead.
# (pid=22933) WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# (pid=22933) Instructions for updating:
# (pid=22933) Please use `layer.__call__` method instead.
# (pid=22933) WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ray/rllib/models/tf/tf_action_dist.py:138: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# (pid=22933) Instructions for updating:
# (pid=22933) Use `tf.cast` instead.
# (pid=22933) WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ray/rllib/models/tf/tf_action_dist.py:138: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# (pid=22933) Instructions for updating:
# (pid=22933) Use `tf.cast` instead.
# (pid=22933) 2019-12-13 19:06:45,770	INFO dynamic_tf_policy.py:324 -- Initializing loss function with dummy input:
# (pid=22933)
# (pid=22933) { 'action_prob': <tf.Tensor 'default_policy/action_prob:0' shape=(?,) dtype=float32>,
# (pid=22933)   'actions': <tf.Tensor 'default_policy/actions:0' shape=(?, 4) dtype=float32>,
# (pid=22933)   'advantages': <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
# (pid=22933)   'behaviour_logits': <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 8) dtype=float32>,
# (pid=22933)   'dones': <tf.Tensor 'default_policy/dones:0' shape=(?,) dtype=bool>,
# (pid=22933)   'new_obs': <tf.Tensor 'default_policy/new_obs:0' shape=(?, 27) dtype=float32>,
# (pid=22933)   'obs': <tf.Tensor 'default_policy/observation:0' shape=(?, 27) dtype=float32>,
# (pid=22933)   'prev_actions': <tf.Tensor 'default_policy/action:0' shape=(?, 4) dtype=float32>,
# (pid=22933)   'prev_rewards': <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
# (pid=22933)   'rewards': <tf.Tensor 'default_policy/rewards:0' shape=(?,) dtype=float32>,
# (pid=22933)   'value_targets': <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
# (pid=22933)   'vf_preds': <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>}
# (pid=22933)
# (pid=22933) WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ray/rllib/policy/tf_policy.py:570: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (pid=22933) Instructions for updating:
# (pid=22933) Prefer Variable.assign which has equivalent behavior in 2.X.
# (pid=22933) WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ray/rllib/policy/tf_policy.py:570: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (pid=22933) Instructions for updating:
# (pid=22933) Prefer Variable.assign which has equivalent behavior in 2.X.
# (pid=22933) 2019-12-13 19:06:46,703	INFO rollout_worker.py:451 -- Generating sample batch of size 200
# (pid=22933) 2019-12-13 19:06:46,774	INFO sampler.py:304 -- Raw obs from env: { 0: { 'agent0': np.ndarray((27,), dtype=int64, min=0.0, max=0.0, mean=0.0)}}
# (pid=22933) 2019-12-13 19:06:46,774	INFO sampler.py:305 -- Info return from env: {0: {'agent0': None}}
# (pid=22933) 2019-12-13 19:06:46,774	INFO sampler.py:403 -- Preprocessed obs: np.ndarray((27,), dtype=int64, min=0.0, max=0.0, mean=0.0)
# (pid=22933) 2019-12-13 19:06:46,774	INFO sampler.py:407 -- Filtered obs: np.ndarray((27,), dtype=int64, min=0.0, max=0.0, mean=0.0)
# (pid=22933) 2019-12-13 19:06:46,775	INFO sampler.py:521 -- Inputs to compute_actions():
# (pid=22933)
# (pid=22933) { 'default_policy': [ { 'data': { 'agent_id': 'agent0',
# (pid=22933)                                   'env_id': 0,
# (pid=22933)                                   'info': None,
# (pid=22933)                                   'obs': np.ndarray((27,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=22933)                                   'prev_action': np.ndarray((4,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (pid=22933)                                   'prev_reward': 0.0,
# (pid=22933)                                   'rnn_state': []},
# (pid=22933)                         'type': 'PolicyEvalData'}]}
# (pid=22933)
# (pid=22933) 2019-12-13 19:06:46,775	INFO tf_run_builder.py:92 -- Executing TF run without tracing. To dump TF timeline traces to disk, set the TF_TIMELINE_DIR environment variable.
# (pid=22933) 2019-12-13 19:06:46,806	INFO sampler.py:548 -- Outputs of compute_actions():
# (pid=22933)
# (pid=22933) { 'default_policy': ( np.ndarray((1, 4), dtype=float32, min=-2.549, max=0.611, mean=-0.625),
# (pid=22933)                       [],
# (pid=22933)                       { 'action_prob': np.ndarray((1,), dtype=float32, min=0.001, max=0.001, mean=0.001),
# (pid=22933)                         'behaviour_logits': np.ndarray((1, 8), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (pid=22933)                         'vf_preds': np.ndarray((1,), dtype=float32, min=0.0, max=0.0, mean=0.0)})}
# (pid=22933)
# (pid=22933) Warning: Vehicle '20' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=131.00.
# (pid=22933) Warning: Vehicle '35' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=166.00.
# (pid=22933) Warning: Vehicle '35' performs emergency stop at the end of lane '34100169#0_1' because of a red traffic light (decel=-12.96, offset=3.05), time=166.00.
# (pid=22933) 2019-12-13 19:06:47,869	INFO sample_batch_builder.py:161 -- Trajectory fragment after postprocess_trajectory():
# (pid=22933)
# (pid=22933) { 'agent0': { 'data': { 'action_prob': np.ndarray((200,), dtype=float32, min=0.0, max=0.023, mean=0.007),
# (pid=22933)                         'actions': np.ndarray((200, 4), dtype=float32, min=-3.003, max=2.975, mean=0.005),
# (pid=22933)                         'advantages': np.ndarray((200,), dtype=float32, min=-121.677, max=-8.0, mean=-72.45),
# (pid=22933)                         'agent_index': np.ndarray((200,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=22933)                         'behaviour_logits': np.ndarray((200, 8), dtype=float32, min=-0.009, max=0.009, mean=-0.001),
# (pid=22933)                         'dones': np.ndarray((200,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (pid=22933)                         'eps_id': np.ndarray((200,), dtype=int64, min=1075199607.0, max=1075199607.0, mean=1075199607.0),
# (pid=22933)                         'infos': np.ndarray((200,), dtype=object, head={}),
# (pid=22933)                         'new_obs': np.ndarray((200, 27), dtype=int64, min=0.0, max=3.0, mean=0.085),
# (pid=22933)                         'obs': np.ndarray((200, 27), dtype=int64, min=0.0, max=3.0, mean=0.083),
# (pid=22933)                         'prev_actions': np.ndarray((200, 4), dtype=float32, min=-3.003, max=2.975, mean=0.005),
# (pid=22933)                         'prev_rewards': np.ndarray((200,), dtype=float32, min=-8.0, max=0.0, mean=-2.25),
# (pid=22933)                         'rewards': np.ndarray((200,), dtype=int64, min=-8.0, max=0.0, mean=-2.29),
# (pid=22933)                         't': np.ndarray((200,), dtype=int64, min=0.0, max=199.0, mean=99.5),
# (pid=22933)                         'unroll_id': np.ndarray((200,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=22933)                         'value_targets': np.ndarray((200,), dtype=float32, min=-121.678, max=-7.996, mean=-72.45),
# (pid=22933)                         'vf_preds': np.ndarray((200,), dtype=float32, min=-0.004, max=0.005, mean=-0.0)},
# (pid=22933)               'type': 'SampleBatch'}}
# (pid=22933)
# (pid=22933) 2019-12-13 19:06:47,871	INFO rollout_worker.py:485 -- Completed sample batch:
# (pid=22933)
# (pid=22933) { 'data': { 'action_prob': np.ndarray((200,), dtype=float32, min=0.0, max=0.023, mean=0.007),
# (pid=22933)             'actions': np.ndarray((200, 4), dtype=float32, min=-3.003, max=2.975, mean=0.005),
# (pid=22933)             'advantages': np.ndarray((200,), dtype=float32, min=-121.677, max=-8.0, mean=-72.45),
# (pid=22933)             'agent_index': np.ndarray((200,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=22933)             'behaviour_logits': np.ndarray((200, 8), dtype=float32, min=-0.009, max=0.009, mean=-0.001),
# (pid=22933)             'dones': np.ndarray((200,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (pid=22933)             'eps_id': np.ndarray((200,), dtype=int64, min=1075199607.0, max=1075199607.0, mean=1075199607.0),
# (pid=22933)             'infos': np.ndarray((200,), dtype=object, head={}),
# (pid=22933)             'new_obs': np.ndarray((200, 27), dtype=int64, min=0.0, max=3.0, mean=0.085),
# (pid=22933)             'obs': np.ndarray((200, 27), dtype=int64, min=0.0, max=3.0, mean=0.083),
# (pid=22933)             'prev_actions': np.ndarray((200, 4), dtype=float32, min=-3.003, max=2.975, mean=0.005),
# (pid=22933)             'prev_rewards': np.ndarray((200,), dtype=float32, min=-8.0, max=0.0, mean=-2.25),
# (pid=22933)             'rewards': np.ndarray((200,), dtype=int64, min=-8.0, max=0.0, mean=-2.29),
# (pid=22933)             't': np.ndarray((200,), dtype=int64, min=0.0, max=199.0, mean=99.5),
# (pid=22933)             'unroll_id': np.ndarray((200,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=22933)             'value_targets': np.ndarray((200,), dtype=float32, min=-121.678, max=-7.996, mean=-72.45),
# (pid=22933)             'vf_preds': np.ndarray((200,), dtype=float32, min=-0.004, max=0.005, mean=-0.0)},
# (pid=22933)   'type': 'SampleBatch'}
# (pid=22933)
# (pid=22933) Warning: Vehicle '44' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=353.00.
# (pid=22933) Warning: Vehicle '44' performs emergency stop at the end of lane '34100169#0_1' because of a red traffic light (decel=-16.58, offset=4.32), time=353.00.
# (pid=22933) Warning: Teleporting vehicle '81'; collision with vehicle '93', lane=':27153964_4_0', gap=-1.00, time=410.00 stage=move.
# (pid=22933) Warning: Vehicle '81' ends teleporting on edge '422856037', time 410.00.
# (pid=22933) Warning: Vehicle '83' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=413.00.
# (pid=22933) Warning: Vehicle '83' performs emergency stop at the end of lane '385995924_0' because of a red traffic light (decel=-9.37, offset=0.37), time=413.00.
# (pid=22933) Warning: Vehicle '46' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=501.00.
# (pid=22933) Warning: Vehicle '46' performs emergency stop at the end of lane '34100169#0_1' because of a red traffic light (decel=-11.01, offset=2.01), time=501.00.
# (pid=22933) Warning: Vehicle '89' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=540.00.
# (pid=22933) Warning: Teleporting vehicle '95'; collision with vehicle '177', lane=':27154068_6_0', gap=-1.00, time=710.00 stage=insertion.
# (pid=22933) Warning: Vehicle '95' ends teleporting on edge '-420074045#2', time 710.00.
# (pid=22933) Warning: Vehicle '171' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=754.00.
# (pid=22933) Warning: Vehicle '194' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=839.00.
# (pid=22933) Warning: Vehicle '95' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=864.00.
# (pid=22933) Warning: Vehicle '206' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=908.00.
# (pid=22933) Warning: Vehicle '206' performs emergency stop at the end of lane '-gneE64_0' because of a red traffic light (decel=-12.77, offset=1.02), time=908.00.
# (pid=22933) Warning: Vehicle '304' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=1222.00.
# (pid=22933) Warning: Vehicle '239' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=1260.00.
# (pid=22933) Warning: Vehicle '239' performs emergency stop at the end of lane '-gneE35_0' because of a red traffic light (decel=-10.61, offset=1.61), time=1260.00.
# (pid=22933) Warning: Vehicle '325' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=1349.00.
# (pid=22933) Warning: Vehicle '209' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=1382.00.
# (pid=22933) Warning: Vehicle '209' performs emergency stop at the end of lane 'gneE77_1' because of a red traffic light (decel=-12.88, offset=1.19), time=1382.00.
# (pid=22933) Warning: Vehicle '381' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=1530.00.
# (pid=22933) Warning: Vehicle '381' performs emergency stop at the end of lane '385995924_0' because of a red traffic light (decel=-13.25, offset=4.25), time=1530.00.
# (pid=22933) Warning: Vehicle '442' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=1800.00.
# (pid=22933) Warning: Vehicle '433' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=1944.00.
# (pid=22933) Warning: Vehicle '433' performs emergency stop at the end of lane 'gneE77_1' because of a red traffic light (decel=-11.65, offset=2.65), time=1944.00.
# (pid=22933) Warning: Vehicle '376' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=2444.00.
# (pid=22933) Warning: Vehicle '689' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=2790.00.
# (pid=22933) Warning: Vehicle '697' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=2852.00.
# (pid=22933) Warning: Vehicle '697' performs emergency stop at the end of lane 'gneE77_1' because of a red traffic light (decel=-16.04, offset=3.24), time=2852.00.
# (pid=22933) Warning: Vehicle '700' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=2912.00.
# (pid=22933) Warning: Vehicle '774' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=3105.00.
# (pid=22933) Warning: Vehicle '774' performs emergency stop at the end of lane 'gneE77_1' because of a red traffic light (decel=-14.80, offset=3.40), time=3105.00.
# (pid=22933) Warning: Vehicle '614' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=3330.00.
# (pid=22933) Warning: Vehicle '614' performs emergency stop at the end of lane '-gneE35_0' because of a red traffic light (decel=-13.43, offset=4.43), time=3330.00.
# (pid=22933) Warning: Teleporting vehicle '892'; collision with vehicle '908', lane=':27154068_6_0', gap=-1.00, time=3634.00 stage=insertion.
# (pid=22933) Warning: Vehicle '892' ends teleporting on edge '-420074045#2', time 3634.00.
# (pid=22933) Warning: Vehicle '908' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=3657.00.
# (pid=22933) Warning: Vehicle '908' performs emergency stop at the end of lane '-4427539#2_1' because of a red traffic light (decel=-13.94, offset=4.94), time=3657.00.
# (pid=22933) Warning: Vehicle '845' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=4820.00.
# (pid=22933) Warning: Vehicle '845' performs emergency stop at the end of lane '34100169#0_1' because of a red traffic light (decel=-13.98, offset=4.98), time=4820.00.
# (pid=22933) Warning: Vehicle '855' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=5182.00.
# (pid=22933) Warning: Vehicle '936' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=5683.00.
# (pid=22933) Warning: Vehicle '936' performs emergency stop at the end of lane '34100169#0_1' because of a red traffic light (decel=-16.23, offset=1.99), time=5683.00.
# (pid=22933) Warning: Vehicle '291' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=5765.00.
# (pid=22933) Warning: Departure time for vehicle '0' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '1' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '2' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '4' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '5' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '7' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '9' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '10' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '13' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '14' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '15' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '16' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '18' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '19' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '20' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '23' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '24' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '25' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '27' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '28' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '29' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '30' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '31' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '34' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '35' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '37' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '39' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '40' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '42' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '43' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '44' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '45' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '46' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '50' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '52' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '53' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '54' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '55' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '57' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '58' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '59' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '61' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '63' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '64' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '66' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '67' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '68' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '69' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '70' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '72' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '73' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '74' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '76' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '77' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '79' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '80' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '81' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '82' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '83' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '84' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '85' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '86' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '87' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '89' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '90' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '92' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '93' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '95' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '96' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '98' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '99' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '101' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '103' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '104' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '105' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '108' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '109' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '111' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '112' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '113' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '115' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '116' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '117' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '118' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '120' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '121' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '122' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '123' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '124' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '126' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '127' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '128' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '129' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '130' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '131' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '132' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '133' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '134' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '135' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '136' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '137' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '138' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '139' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '140' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '141' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '143' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '144' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '145' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '146' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '147' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '148' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '149' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '150' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '151' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '152' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '153' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '154' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '156' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '157' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '158' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '159' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '160' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '162' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '163' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '164' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '165' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '166' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '167' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '168' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '170' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '171' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '176' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '177' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '180' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '181' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '182' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '183' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '185' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '186' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '187' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '188' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '189' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '190' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '191' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '192' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '193' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '194' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '195' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '197' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '198' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '199' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '200' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '201' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '202' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '203' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '204' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '205' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '206' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '207' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '208' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '209' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '210' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '211' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '212' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '213' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '214' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '215' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '216' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '217' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '218' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '219' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '222' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '223' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '224' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '225' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '226' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '227' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '228' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '229' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '230' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '231' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '232' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '233' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '234' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '235' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '236' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '237' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '238' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '239' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '240' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '242' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '243' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '244' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '245' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '246' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '247' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '250' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '251' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '252' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '253' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '255' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '257' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '263' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '265' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '266' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '267' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '268' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '270' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '271' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '272' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '274' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '275' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '277' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '278' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '279' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '280' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '281' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '282' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '283' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '284' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '285' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '286' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '287' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '288' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '289' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '290' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '291' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '292' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '294' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '296' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '297' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '298' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '299' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '300' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '301' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '302' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '303' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '304' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '305' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '306' is in the past; using current time instead.
# (pid=22933) Warning: Departure time for vehicle '308' is in the past; using current time instead.
# ...
# (pid=22933) Warning: Teleporting vehicle '676'; collision with vehicle '133', lane=':3016858865_1_1', gap=-1.00, time=10022.00 stage=insertion.
# (pid=22933) Warning: Vehicle '728' ends teleporting on edge 'gneE35', time 10022.00.
# (pid=22933) Warning: Vehicle '250' ends teleporting on edge 'gneE29', time 10022.00.
# (pid=22933) Warning: Vehicle '887' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10023.00.
# (pid=22933) Warning: Vehicle '165' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10023.00.
# (pid=22933) Warning: Vehicle '329' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10023.00.
# (pid=22933) Warning: Vehicle '344' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10023.00.
# (pid=22933) Warning: Vehicle '420' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10024.00.
# (pid=22933) Warning: Vehicle '222' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10024.00.
# (pid=22933) Warning: Vehicle '372' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10024.00.
# (pid=22933) Warning: Vehicle '382' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10024.00.
# (pid=22933) Warning: Teleporting vehicle '372'; collision with vehicle '329', lane='-gneE46_0', gap=-0.07, time=10024.00 stage=move.
# (pid=22933) Warning: Vehicle '506' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10025.00.
# (pid=22933) Warning: Teleporting vehicle '506'; collision with vehicle '420', lane='405683165_1', gap=-1.44, time=10025.00 stage=move.
# (pid=22933) Warning: Teleporting vehicle '382'; collision with vehicle '344', lane='gneE32_0', gap=-0.89, time=10025.00 stage=move.
# (pid=22933) Warning: Vehicle '382' ends teleporting on edge 'gneE29', time 10025.00.
# (pid=22933) Warning: Vehicle '77' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10026.00.
# (pid=22933) Warning: Vehicle '340' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10026.00.
# (pid=22933) Warning: Vehicle '282' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10026.00.
# (pid=22933) Warning: Vehicle '372' ends teleporting on edge '-gneE47', time 10026.00.
# (pid=22933) Warning: Vehicle '523' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10027.00.
# (pid=22933) Warning: Vehicle '640' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10027.00.
# (pid=22933) Warning: Teleporting vehicle '523'; collision with vehicle '77', lane='405683165_1', gap=-5.54, time=10027.00 stage=move.
# (pid=22933) Warning: Teleporting vehicle '510'; collision with vehicle '357', lane='355123660#0_0', gap=-0.04, time=10027.00 stage=move.
# (pid=22933) Warning: Teleporting vehicle '640'; collision with vehicle '510', lane='355123660#0_0', gap=-0.06, time=10027.00 stage=move.
# (pid=22933) Warning: Vehicle '74' ends teleporting on edge 'gneE46', time 10027.00.
# (pid=22933) Warning: Vehicle '426' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10028.00.
# (pid=22933) Warning: Vehicle '806' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10028.00.
# (pid=22933) Warning: Vehicle '814' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10028.00.
# (pid=22933) Warning: Vehicle '507' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10029.00.
# (pid=22933) Warning: Vehicle '872' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10029.00.
# (pid=22933) Warning: Teleporting vehicle '507'; collision with vehicle '426', lane='405683165_1', gap=-3.78, time=10029.00 stage=move.
# (pid=22933) Warning: Vehicle '523' ends teleporting on edge '422856037', time 10029.00.
# (pid=22933) Warning: Vehicle '569' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10030.00.
# (pid=22933) Warning: Vehicle '251' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10030.00.
# (pid=22933) Warning: Vehicle '223' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10030.00.
# (pid=22933) Warning: Vehicle '182' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10030.00.
# (pid=22933) Warning: Teleporting vehicle '251'; collision with vehicle '872', lane='355123660#0_0', gap=-1.08, time=10030.00 stage=move.
# (pid=22933) Warning: Vehicle '503' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10031.00.
# (pid=22933) Warning: Teleporting vehicle '569'; collision with vehicle '426', lane='405683165_1', gap=-1.80, time=10031.00 stage=move.
# (pid=22933) Warning: Vehicle '510' ends teleporting on edge 'gneE61', time 10031.00.
# (pid=22933) Warning: Vehicle '732' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10032.00.
# (pid=22933) Warning: Vehicle '614' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10032.00.
# (pid=22933) Warning: Vehicle '63' ends teleporting on edge '407511303#0', time 10032.00.
# (pid=22933) Warning: Vehicle '816' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10033.00.
# (pid=22933) Warning: Vehicle '687' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10033.00.
# (pid=22933) Warning: Vehicle '346' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10033.00.
# (pid=22933) Warning: Vehicle '919' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10034.00.
# (pid=22933) Warning: Vehicle '597' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10034.00.
# (pid=22933) Warning: Vehicle '507' ends teleporting on edge '6268492#0', time 10034.00.
# (pid=22933) Warning: Vehicle '764' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10035.00.
# (pid=22933) Warning: Vehicle '400' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10035.00.
# (pid=22933) Warning: Teleporting vehicle '400'; collision with vehicle '597', lane='-gneE58_0', gap=-0.12, time=10035.00 stage=move.
# (pid=22933) Warning: Vehicle '640' ends teleporting on edge '-gneE60', time 10035.00.
# (pid=22933) Warning: Vehicle '407' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10036.00.
# (pid=22933) Warning: Vehicle '752' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10036.00.
# (pid=22933) Warning: Vehicle '799' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10036.00.
# (pid=22933) Warning: Teleporting vehicle '752'; collision with vehicle '671', lane='gneE32_0', gap=-0.33, time=10036.00 stage=move.
# (pid=22933) Warning: Vehicle '752' ends teleporting on edge 'gneE29', time 10036.00.
# (pid=22933) Warning: Vehicle '808' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10037.00.
# (pid=22933) Warning: Vehicle '818' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10038.00.
# (pid=22933) Warning: Teleporting vehicle '808'; collision with vehicle '799', lane='gneE32_0', gap=-0.99, time=10038.00 stage=move.
# (pid=22933) Warning: Vehicle '808' ends teleporting on edge 'gneE29', time 10038.00.
# (pid=22933) Warning: Vehicle '480' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10040.00.
# (pid=22933) Warning: Teleporting vehicle '230'; collision with vehicle '180', lane='-gneE35_0', gap=-0.03, time=10040.00 stage=move.
# (pid=22933) Warning: Vehicle '230' ends teleporting on edge '407511303#0', time 10040.00.
# (pid=22933) Warning: Vehicle '616' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10041.00.
# (pid=22933) Warning: Vehicle '694' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10042.00.
# (pid=22933) Warning: Vehicle '513' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10042.00.
# (pid=22933) Warning: Teleporting vehicle '616'; collision with vehicle '480', lane='gneE32_0', gap=-2.85, time=10042.00 stage=move.
# (pid=22933) Warning: Vehicle '616' ends teleporting on edge 'gneE29', time 10042.00.
# (pid=22933) Warning: Vehicle '715' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10043.00.
# (pid=22933) Warning: Vehicle '794' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10044.00.
# (pid=22933) Warning: Vehicle '720' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10044.00.
# (pid=22933) Warning: Teleporting vehicle '720'; collision with vehicle '715', lane='gneE37_0', gap=-1.09, time=10044.00 stage=move.
# (pid=22933) Warning: Vehicle '913' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10045.00.
# (pid=22933) Warning: Vehicle '593' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10045.00.
# (pid=22933) Warning: Vehicle '908' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10046.00.
# (pid=22933) Warning: Teleporting vehicle '913'; collision with vehicle '794', lane='gneE32_0', gap=-4.17, time=10046.00 stage=move.
# (pid=22933) Warning: Teleporting vehicle '168'; collision with vehicle '224', lane=':27153964_13_0', gap=-1.00, time=10046.00 stage=move.
# (pid=22933) Warning: Vehicle '506' ends teleporting on edge '4427539#1', time 10046.00.
# (pid=22933) Warning: Vehicle '913' ends teleporting on edge 'gneE29', time 10046.00.
# (pid=22933) Warning: Vehicle '717' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10048.00.
# (pid=22933) Warning: Vehicle '953' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10049.00.
# (pid=22933) Warning: Teleporting vehicle '219'; collision with vehicle '518', lane=':gneJ18_1_1', gap=-1.00, time=10050.00 stage=insertion.
# (pid=22933) Warning: Vehicle '251' ends teleporting on edge '-gneE60', time 10054.00.
# (pid=22933) Warning: Vehicle '569' ends teleporting on edge '6268492#0', time 10054.00.
# (pid=22933) Warning: Vehicle '168' ends teleporting on edge '6268492#0', time 10059.00.
# (pid=22933) Warning: Vehicle '361' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10061.00.
# (pid=22933) Warning: Teleporting vehicle '578'; collision with vehicle '895', lane=':gneJ18_1_1', gap=-1.00, time=10064.00 stage=insertion.
# (pid=22933) Warning: Teleporting vehicle '9'; collision with vehicle '965', lane=':260218684_0_1', gap=-1.00, time=10068.00 stage=insertion.
# (pid=22933) Warning: Vehicle '219' ends teleporting on edge 'gneE77', time 10091.00.
# (pid=22933) Warning: Teleporting vehicle '30'; collision with vehicle '481', lane=':27153964_5_0', gap=-1.00, time=10098.00 stage=move.
# (pid=22933) Warning: Vehicle '30' ends teleporting on edge '6268492#0', time 10098.00.
# (pid=22933) Warning: Vehicle '9' ends teleporting on edge '405683165', time 10106.00.
# (pid=22933) Warning: Vehicle '400' ends teleporting on edge 'gneE51', time 10107.00.
# (pid=22933) Warning: Vehicle '720' ends teleporting on edge '-385995453#1', time 10114.00.
# (pid=22933) Warning: Vehicle '578' ends teleporting on edge 'gneE77', time 10146.00.
# (pid=22933) Warning: Teleporting vehicle '851'; collision with vehicle '267', lane=':27154068_1_0', gap=-1.00, time=10150.00 stage=move.
# (pid=22933) Warning: Vehicle '851' ends teleporting on edge '-420074045#2', time 10150.00.
# (pid=22933) Warning: Teleporting vehicle '938'; collision with vehicle '669', lane=':27154068_1_0', gap=-1.00, time=10182.00 stage=move.
# (pid=22933) Warning: Vehicle '938' ends teleporting on edge '-420074045#2', time 10182.00.
# (pid=22933) Warning: Teleporting vehicle '678'; collision with vehicle '966', lane=':27153964_5_0', gap=-1.00, time=10185.00 stage=move.
# (pid=22933) Warning: Vehicle '678' ends teleporting on edge '6268492#0', time 10185.00.
# (pid=22933) Warning: Vehicle '990' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=10210.00.
# (pid=22933) Warning: Vehicle '990' performs emergency stop at the end of lane 'gneE60_0' because of a red traffic light (decel=-23.84, offset=9.69), time=10210.00.
# 2019-12-13 19:08:28,001	ERROR worker.py:1616 -- print_logs: Error 111 connecting to 192.168.101.101:46228. Connection refused.
# 2019-12-13 19:08:28,008	ERROR worker.py:1716 -- listen_error_messages_raylet: Error 111 connecting to 192.168.101.101:46228. Connection refused.
# 2019-12-13 19:08:28,015	ERROR import_thread.py:89 -- ImportThread: Error 111 connecting to 192.168.101.101:46228. Connection refused.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-de6de897c217> in <module>
#      10         "max_failures": 999,
#      11         "stop": {  # stopping conditions
# ---> 12             "training_iteration": 10,  # number of iterations to stop after
#      13         },
#      14     },
#
# /usr/local/lib/python3.6/dist-packages/ray/tune/tune.py in run_experiments(experiments, search_alg, scheduler, with_server, server_port, verbose, resume, queue_trials, reuse_actors, trial_executor, raise_on_failed_trial)
#     322             trial_executor=trial_executor,
#     323             raise_on_failed_trial=raise_on_failed_trial,
# --> 324             return_trials=True)
#     325     return trials
#
# /usr/local/lib/python3.6/dist-packages/ray/tune/tune.py in run(run_or_experiment, name, stop, config, resources_per_trial, num_samples, local_dir, upload_dir, trial_name_creator, loggers, sync_to_cloud, sync_to_driver, checkpoint_freq, checkpoint_at_end, keep_checkpoints_num, checkpoint_score_attr, global_checkpoint_period, export_formats, max_failures, restore, search_alg, scheduler, with_server, server_port, verbose, resume, queue_trials, reuse_actors, trial_executor, raise_on_failed_trial, return_trials, ray_auto_init, sync_function)
#     242     last_debug = 0
#     243     while not runner.is_finished():
# --> 244         runner.step()
#     245         if time.time() - last_debug > DEBUG_PRINT_INTERVAL:
#     246             if verbose:
#
# /usr/local/lib/python3.6/dist-packages/ray/tune/trial_runner.py in step(self)
#     326                 self.trial_executor.start_trial(next_trial)
#     327         elif self.trial_executor.get_running_trials():
# --> 328             self._process_events()  # blocking
#     329         else:
#     330             for trial in self._trials:
#
# /usr/local/lib/python3.6/dist-packages/ray/tune/trial_runner.py in _process_events(self)
#     490
#     491     def _process_events(self):
# --> 492         trial = self.trial_executor.get_next_available_trial()  # blocking
#     493         with warn_if_slow("process_trial"):
#     494             self._process_trial(trial)
#
# /usr/local/lib/python3.6/dist-packages/ray/tune/ray_trial_executor.py in get_next_available_trial(self)
#     316         # See https://github.com/ray-project/ray/issues/4211 for details.
#     317         start = time.time()
# --> 318         [result_id], _ = ray.wait(shuffled_results)
#     319         wait_time = time.time() - start
#     320         if wait_time > NONTRIVIAL_WAIT_TIME_THRESHOLD_S:
#
# /usr/local/lib/python3.6/dist-packages/ray/worker.py in wait(object_ids, num_returns, timeout)
#    2370             timeout_milliseconds,
#    2371             False,
# -> 2372             worker.current_task_id,
#    2373         )
#    2374         return ready_ids, remaining_ids
#
# python/ray/_raylet.pyx in ray._raylet.RayletClient.wait()
#
# python/ray/_raylet.pyx in ray._raylet.check_status()
#
# /usr/local/lib/python3.6/dist-packages/ray/exceptions.py in __init__(self, client_exc)
#      84     """
#      85
# ---> 86     def __init__(self, client_exc):
#      87         self.client_exc = client_exc
#      88
#
# KeyboardInterrupt:
